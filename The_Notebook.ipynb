# %% [markdown]
# # **Welcome to the notebook**

# %% [markdown]
# ### Task 1 - Set up project environment

# %% [markdown]
# Installing the needed modules

# %%
# !pip install -q -U google-generativeai python-dotenv

# %% [markdown]
# Importing the needed modules and setup the OpenAI API

# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
from matplotlib import pyplot as plt
import plotly.express as px
import google.generativeai as genai
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# Loading API key and organization ID from a dotenv file
load_dotenv(dotenv_path='apikey.env.txt')

# Retrieving API key and organization ID from environment variables
APIKEY = os.getenv("APIKEY")

# Setting the API key and organization ID for Google's Generative AI
genai.configure(api_key=APIKEY)

client = genai.GenerativeModel('gemini-1.5-flash')

client
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %% [markdown]
# Import our dataset

# %%
df = pd.read_csv('/content/products_dataset.csv')
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description
# 0  This heavyweight, water-repellent hooded sweat...
# 1  If you need more length between your existing ...
# 2  Polyester cover resembling rich Italian tapest...
# 3  It features a rectangle shape. This vessel set...
# 4  This 9 in. black full grain leather logger boo...

# %% [markdown]
# List of last 8 products recently viewed by the user.

# %%
searched_products_id = [
    'P1938',
    'P1970',
    'P1044',
    'P1838',
    'P1048',
    'P1017',
    'P1310',
    'P1444',
]

# %% [markdown]
# ### Task 2 - Prepare the dataset

# %% [markdown]
# Let's label the data points that are recently veiwed.

# %%
df['product_status'] = 'not_viewed'
df.loc[df['product_id'].isin(searched_products_id), 'product_status'] = 'recently_viewed'
df[df.product_status == 'recently_viewed']
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed

# %% [markdown]
# Now let's combine the product `title` and `description` and store it into a column called `combined`.

# %%
df['combined'] = df['title'] + ' ' + df['description']
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...

# %% [markdown]
# ### Task 3 - Text embedding and visualization

# %%
text = "Hello World!"
result = genai.embed_content(
    model="models/text-embedding-004", content=text, output_dimensionality=1
)
print(result["embedding"])
# Out:
# [0.002266675]

# %% [markdown]
# Creating the text embedding vectors

# %%
from tqdm import tqdm

results = []
for item in tqdm(df['combined'], desc="Embedding content"):
    results.append(genai.embed_content(
        model="models/text-embedding-004",
        content=[item],  # Embed one item at a time
        output_dimensionality=128,
    ))
# Out:
# Embedding content: 100%|██████████| 2000/2000 [32:17<00:00,  1.03it/s]

# %%
for i in (results[0]['embedding'][0]):
  print(i)
  break
# Out:
# 0.02661769

# %%
df['text_embedding'] = [result['embedding'][0] for result in results]
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding
# 0  [0.02661769, 0.021672012, -0.0073499964, -0.00...
# 1  [0.0054305517, -0.03324972, -0.039408334, 0.02...
# 2  [-0.024200058, 0.04525282, 0.02500831, 0.00932...
# 3  [-0.012281764, -0.023819033, 0.013256148, -0.0...
# 4  [-0.001543015, 0.026881523, -0.029850263, -0.0...

# %%
df['text_embedding'].shape
# Out:
# (2000,)

# %% [markdown]
# > We know that each vector has 512 dimensions. In order to be able to visualize the vectors in a scatter plot, we need to use Principal Component Analysis (PCA) to reduce the dimension from 512 to 2.

# %%
pca=PCA(n_components=2)
vector_2d = pca.fit_transform(np.array(df['text_embedding'].tolist()) )
df['pca1'] = vector_2d[:,0]
df['pca2'] = vector_2d[:,1]
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding      pca1      pca2
# 0  [0.02661769, 0.021672012, -0.0073499964, -0.00... -0.085661  0.012239
# 1  [0.0054305517, -0.03324972, -0.039408334, 0.02... -0.129703 -0.063566
# 2  [-0.024200058, 0.04525282, 0.02500831, 0.00932... -0.099862  0.114211
# 3  [-0.012281764, -0.023819033, 0.013256148, -0.0... -0.068318 -0.105377
# 4  [-0.001543015, 0.026881523, -0.029850263, -0.0... -0.134826  0.032858

# %% [markdown]
# Now that we have the text embedding vectors in two dimensions, we can use them to create a 2D plot.

# %%
px.scatter(df, x='pca1', y='pca2', color='product_status', hover_data=['title', 'description'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21a666e4-d04c-418a-a08e-0f721177e72a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21a666e4-d04c-418a-a08e-0f721177e72a")) {                    Plotly.newPlot(                        "21a666e4-d04c-418a-a08e-0f721177e72a",                        [{"customdata":[["Men's 3X Large Carbon Heather Cotton\u002fPolyester Rain Defender Paxton Heavyweight Hooded Zip-Front Sweatshirt","This heavyweight, water-repellent hooded sweatshirt has a zip front for fast layering. ORIGINAL FIT. 13 oz., 75% cotton\u002f25% polyester blend with Rain Defender durable water repellent. Attached, jersey-lined three-piece hood with drawcord closure. Antique-finish brass front zipper. Two front hand-warmer pockets have a hidden security pocket inside. Stretchable, spandex-reinforced rib-knit cuffs and waistband. Locker loop facilitates hanging."],["Turmode 30 ft. RP TNC Female to RP TNC Male Adapter Cable","If you need more length between your existing wireless device and Hi-Gain Antenna, this is the product for you. It's compatible with most Wi-Fi Antennas, so it is easy for you to extend your wireless network. Just replace your existing cable that runs between your wireless device and Antenna and you're ready to use your network with extended range."],["Large Tapestry Bolster Bed","Polyester cover resembling rich Italian tapestries wraps your pet in comfort and style. 100% recycled polyester high loft MemoryFiber fill keeps pets elevated off cold floors for relief on tired joints and pressure points. A great fit for pets up to 100 lbs. Zippered removable cover is machine washable in cold water only. To dry, use a delicate cycle or gentle setting with very low heat."],["16-Gauge-Sinks Vessel Sink in White with Faucet","It features a rectangle shape. This vessel set is designed to be installed as a undermount vessel set. It is constructed with ceramic. This vessel set comes with an enamel glaze finish in White color. It is designed for a deck mount faucet."],["Men's Crazy Horse 9'' Logger Boot - Steel Toe - Black Size 10.5(W)","This 9 in. black full grain leather logger boot is Tough. With plain soft toe and rubber outsole it provides dependable traction with a comfortable fit. It is made with Goodyear Welt Construction so it is sturdy and secure."],["Mariana 6 ft. Multi-Color 3-Panel Screen Divider","With robust structure and sophisticated canvas printing, this 3-panel screen is colorfully designed to be a great way to carve out space in your room or anywhere around the home. Not only will this elegant piece give you the needed exclusivity but it will also add inspiring style and beauty to your decor. This screen creatively features canvas print of a different and complementary images on each side. With its lightweight construction, our screen will definitely fill your space with inspiring visual flair for many-Years to come. 3-panel screen finished on both sides Canvas printing."],["5 gal. #650C-2 Powdery Mist Semi-Gloss Interior Paint","BEHR PRO i300 Semi-Gloss Interior Paint has a sleek, radiant sheen appearance. This professional quality latex paint has superior hide and coverage, excellent sprayability, spray and back-roll, and superior touch-up. Use on properly prepared and primed drywall, concrete, masonry, wood and metal surfaces in both residential and commercial applications."],["7\u002f8 in. x 4-1\u002f2 in. x 0.045 in. Metal and Stainless Cutting Wheel (50-Pack)","DEWALT High Performance 0.045 in. Metal Cutting Wheels have a thin 0.045 in. cutting edge design for fast burr free cutting. They have a proprietary aluminum oxide grain combination for aggressive cutting action and the proprietary material mix ensures durable long life  ...

# %% [markdown]
# ### Task 4 - Find similar products

# %%
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding      pca1      pca2
# 0  [0.02661769, 0.021672012, -0.0073499964, -0.00... -0.085661  0.012239
# 1  [0.0054305517, -0.03324972, -0.039408334, 0.02... -0.129703 -0.063566
# 2  [-0.024200058, 0.04525282, 0.02500831, 0.00932... -0.099862  0.114211
# 3  [-0.012281764, -0.023819033, 0.013256148, -0.0... -0.068318 -0.105377
# 4  [-0.001543015, 0.026881523, -0.029850263, -0.0... -0.134826  0.032858

# %% [markdown]
# Get the data related to `recently_viewed` and `not_viewed` products

# %%
df_recently_viewed = df[df.product_status == 'recently_viewed']
df_not_viewed = df[df.product_status == 'not_viewed']

# %% [markdown]
# Convert the embedding vectors to Numpy arrays

# %%
df_recently_viewed['text_embedding'] = df_recently_viewed['text_embedding'].apply(np.array)
df_not_viewed['text_embedding'] = df_not_viewed['text_embedding'].apply(np.array)

# %% [markdown]
# Find the similarity between each viewed product and all the unviewed products.

# %%
similarity_matrix = cosine_similarity(df_recently_viewed['text_embedding'].tolist(), df_not_viewed['text_embedding'].tolist())
top_ids=[]
for row in similarity_matrix:
  top_id = np.argmax(row)
  top_ids.append(top_id)

# %%
most_similar_products = df_not_viewed.iloc[top_ids].product_id.tolist()
most_similar_products
# Out:
# ['P1480', 'P1183', 'P300', 'P575', 'P1327', 'P1816', 'P976', 'P469']

# %% [markdown]
# ### Task 5 - Recommend products based on the searched products

# %% [markdown]
# Let's update the status of the top similar products to `recommended`.

# %%
df.loc[df['product_id'].isin(most_similar_products), 'product_status'] = 'recommended'
df[df.product_status == 'recommended']
# Out:
#      product_id                                              title  \
# 300        P300  1 qt. #MQ3-54 Dayflower Extra Durable Satin En...
# 469        P469  8 oz. 560C-3 Holiday Road Matte Stain-Blocking...
# 575        P575  5 gal. #S480-1 Rain Dance Extra Durable Semi-G...
# 976        P976  1 qt. #240C-2 Heavenly Song Eggshell Enamel In...
# 1183      P1183  1 qt. #PPU3-02 Marmalade Glaze Eggshell Enamel...
# 1327      P1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1480      P1480  1 gal. #S440-7 Thermal One-Coat Hide Eggshell ...
# 1816      P1816  1 qt. #N370-5 Incognito Extra Durable Semi-Glo...
#
#                                             description product_status  \
# 300   BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 469   Introducing the best of BEHR Paint. Featuring ...    recommended
# 575   BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 976   Introducing the best of BEHR Paint. Featuring ...    recommended
# 1183  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1327  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 1480  Love your space like never before with the hig...    recommended
# 1816  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
#
#                                                combined  \
# 300   1 qt. #MQ3-54 Dayflower Extra Durable Satin En...
# 469   8 oz. 560C-3 Holiday Road Matte Stain-Blocking...
# 575   5 gal. #S480-1 Rain Dance Extra Durable Semi-G...
# 976   1 qt. #240C-2 Heavenly Song Eggshell Enamel In...
# 1183  1 qt. #PPU3-02 Marmalade Glaze Eggshell Enamel...
# 1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1480  1 gal. #S440-7 Thermal One-Coat Hide Eggshell ...
# 1816  1 qt. #N370-5 Incognito Extra Durable Semi-Glo...
#
#                                          text_embedding      pca1      pca2
# 300   [0.011734788, -0.02116309, -0.020741303, -0.02...  0.199416  0.024334
# 469   [-0.004898785, -0.014543502, 0.022011619, -0.0...  0.171787  0.026440
# 575   [-0.002327398, -0.032607585, -0.009485828, -0....  0.170865 -0.000843
# 976   [0.0056962622, -0.044923574, -0.015496335, -0....  0.207290  0.011227
# 1183  [-0.009784818, -0.04942396, -0.012847489, -0.0...  0.224410  0.029056
# 1327  [-0.002912318, -0.01188779, -0.04778934, -0.02...  0.209698  0.022958
# 1480  [0.010610258, -0.05519484, -0.010768119, -0.04...  0.207471  0.018006
# 1816  [-0.016892718, -0.037415806, -0.020209111, -0....  0.219438  0.001347

# %% [markdown]
# Let's visualize the recommended products.

# %%
px.scatter(df, x='pca1', y='pca2', color='product_status', hover_data=['title', 'description'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="64298a2a-00db-419a-81fc-468c32876e58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64298a2a-00db-419a-81fc-468c32876e58")) {                    Plotly.newPlot(                        "64298a2a-00db-419a-81fc-468c32876e58",                        [{"customdata":[["Men's 3X Large Carbon Heather Cotton\u002fPolyester Rain Defender Paxton Heavyweight Hooded Zip-Front Sweatshirt","This heavyweight, water-repellent hooded sweatshirt has a zip front for fast layering. ORIGINAL FIT. 13 oz., 75% cotton\u002f25% polyester blend with Rain Defender durable water repellent. Attached, jersey-lined three-piece hood with drawcord closure. Antique-finish brass front zipper. Two front hand-warmer pockets have a hidden security pocket inside. Stretchable, spandex-reinforced rib-knit cuffs and waistband. Locker loop facilitates hanging."],["Turmode 30 ft. RP TNC Female to RP TNC Male Adapter Cable","If you need more length between your existing wireless device and Hi-Gain Antenna, this is the product for you. It's compatible with most Wi-Fi Antennas, so it is easy for you to extend your wireless network. Just replace your existing cable that runs between your wireless device and Antenna and you're ready to use your network with extended range."],["Large Tapestry Bolster Bed","Polyester cover resembling rich Italian tapestries wraps your pet in comfort and style. 100% recycled polyester high loft MemoryFiber fill keeps pets elevated off cold floors for relief on tired joints and pressure points. A great fit for pets up to 100 lbs. Zippered removable cover is machine washable in cold water only. To dry, use a delicate cycle or gentle setting with very low heat."],["16-Gauge-Sinks Vessel Sink in White with Faucet","It features a rectangle shape. This vessel set is designed to be installed as a undermount vessel set. It is constructed with ceramic. This vessel set comes with an enamel glaze finish in White color. It is designed for a deck mount faucet."],["Men's Crazy Horse 9'' Logger Boot - Steel Toe - Black Size 10.5(W)","This 9 in. black full grain leather logger boot is Tough. With plain soft toe and rubber outsole it provides dependable traction with a comfortable fit. It is made with Goodyear Welt Construction so it is sturdy and secure."],["Mariana 6 ft. Multi-Color 3-Panel Screen Divider","With robust structure and sophisticated canvas printing, this 3-panel screen is colorfully designed to be a great way to carve out space in your room or anywhere around the home. Not only will this elegant piece give you the needed exclusivity but it will also add inspiring style and beauty to your decor. This screen creatively features canvas print of a different and complementary images on each side. With its lightweight construction, our screen will definitely fill your space with inspiring visual flair for many-Years to come. 3-panel screen finished on both sides Canvas printing."],["5 gal. #650C-2 Powdery Mist Semi-Gloss Interior Paint","BEHR PRO i300 Semi-Gloss Interior Paint has a sleek, radiant sheen appearance. This professional quality latex paint has superior hide and coverage, excellent sprayability, spray and back-roll, and superior touch-up. Use on properly prepared and primed drywall, concrete, masonry, wood and metal surfaces in both residential and commercial applications."],["7\u002f8 in. x 4-1\u002f2 in. x 0.045 in. Metal and Stainless Cutting Wheel (50-Pack)","DEWALT High Performance 0.045 in. Metal Cutting Wheels have a thin 0.045 in. cutting edge design for fast burr free cutting. They have a proprietary aluminum oxide grain combination for aggressive cutting action and the proprietary material mix ensures durable long life  ...
